# %%
from Electrostatics import *

# %%
x,y = meshgrid(arange(-1.,1.,0.037),arange(-1.,1.,0.037))
q1 = -3.0*10**(-9)
q2 = 3.0*10**(-9)
Vdip = dipolePotential(x,y,q1,q2,1)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = figure()
ax = fig.gca(projection='3d')
Vtotal = pointPotential(x,y,-2*10**(-9),0,5) + Vdip
p = ax.plot_surface(x, y, Vtotal, rstride=1, cstride=1, linewidth = 0, cmap=cm.jet_r)
cb = fig.colorbar(p, shrink=0.5)

# %% [markdown]
# #Using Boolean masks to find data

# %%
theta = arange(0,2*pi,pi/100)
plot(theta,sin(theta))

# %%
mask = (sin(theta)>0) & (sin(theta)<0.5)
#print mask
plot(theta,sin(theta),theta[mask],sin(theta)[mask])
# Out:
# [<matplotlib.lines.Line2D at 0x10aa6bed0>,
#  <matplotlib.lines.Line2D at 0x10aa6bfd0>]

# %%
y = sin(theta[mask])
jj = (y == max(y))
y[jj] = NaN

# %%
plot(theta,sin(theta))
plot(theta[mask],y,linewidth=4)

# %% [markdown]
# #Interpolation

# %%
theta = arange(0.,2*pi+0.1,pi/10)
mask = (theta == 0.5)
print mask
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False]

# %%
newTheta = 0.5; newSin = 0.
from scipy.interpolate import interp1d
#help(interp1d)
sinInterp = interp1d(theta, sin(theta)) #creating interpolating function

newSin = sinInterp(newTheta)
print newSin
# Out:
# 0.473922198704

# %%
plot(theta,sin(theta),newTheta,newSin, 'r+',markersize = 20,markeredgewidth = 3)
# Out:
# [<matplotlib.lines.Line2D at 0x10f197f50>,
#  <matplotlib.lines.Line2D at 0x10f19a450>]

# %%
thetaNew = arange(0,2*pi,pi/30)
sinNew = interp1d(theta,sin(theta))(thetaNew) #does what was done in last cell but in one step rather than two
plot(theta, sin(theta), thetaNew, sinNew, 'r*')
show()

# %%
plot(thetaNew, sinNew - sin(thetaNew))
ylabel('difference between interp and exact value')

# %%
sinNewC = interp1d(theta, sin(theta), kind = "cubic")(thetaNew)
subplot(2,1,1)
plot(thetaNew, sinNew - sin(thetaNew), thetaNew, sinNewC - sin(thetaNew), 'r*')
subplot(2,1,2)
plot(thetaNew, sinNewC - sin(thetaNew), 'r')
show()
