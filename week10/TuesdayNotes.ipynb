# %% [markdown]
# Exercise 1
# =

# %%
DataIn=loadtxt('radioactivedecay.dat')

# %%
print DataIn
# Out:
# [[  0.    10.48]
#  [  1.     7.54]
#  [  2.     5.49]
#  [  3.     4.02]
#  [  4.     2.74]
#  [  5.     2.02]
#  [  6.     1.5 ]
#  [  7.     1.09]
#  [  8.     0.68]
#  [  9.     0.57]
#  [ 10.     0.37]
#  [ 11.     0.31]
#  [ 12.     0.19]
#  [ 13.     0.15]
#  [ 14.     0.13]
#  [ 15.     0.11]]

# %%
t = DataIn[:,0]
N = DataIn[:,1]
plot(t,N,'b*')
xlabel('time')
ylabel('N remaining')

# %%
plot(log(t+.000001),log(N))
