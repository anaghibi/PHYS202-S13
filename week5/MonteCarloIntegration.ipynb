# %%
f = lambda x: x**(0.5) + sin(x)

# %%
x = arange(0.,15.,0.001)

# %%
myplot = plot(x,f(x),lw=3)
ylabel(r'$x^(1/2) + \sin(x)$', fontsize = 20)
xlabel(r'$x$', fontsize = 20)
xlim(0.,15.)

show()

# %% [markdown]
# ###Creating a bounding box

# %%
xmin = 1.7
xmax = 12.4

#find the max value of f within the bounday to set ymax
subx = x[logical_and((x>xmin),(x<xmax))]
ymax = max(f(subx))*1.05
ymin = 0

#Replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)


#plot the box
plot ([xmin, xmin], [ymin,ymax], color='k',linestyle='--')#vertical left
plot ([xmax, xmax], [ymin,ymax], color='k',linestyle='--')#vertical right
plot ([xmin, xmax], [ymax,ymax], color='k',linestyle='--')#horizontal top

show()

# %%
#random_sample?

N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

#Replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#Plot the box
plot([xmin, xmin], [ymin,ymax], color='k',linestyle='--')
plot([xmax, xmax], [ymin,ymax], color='k',linestyle='--')
plot([xmin, xmax], [ymax,ymax], color='k',linestyle='--')

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6229

# %% [markdown]
# ####Now we can replot the points that lie below the function for proof:

# %%
#Replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#Show the ones below the function in red
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

#plot the box
plot([xmin, xmin], [ymin,ymax], color='k',linestyle='--')
plot([xmax, xmax], [ymin,ymax], color='k',linestyle='--')
plot([xmin, xmax], [ymax,ymax], color='k',linestyle='--')

# %% [markdown]
# Now we can compute our integral from step V: the area of the rectangle times the ratio of the number of red and green dots.

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.7213634564

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print Iexact
print I
print 'error =',Ierr,'%'
# Out:
# 26.5172145362
# 26.7213634564
# error = -0.769873170084 %

# %% [markdown]
# ###Exercise 1

# %%
N = 55900000
samples_x1 = xmin + (xmax-xmin)*random_sample(N);
samples_y1 = ymin + (ymax-ymin)*random_sample(N);

#Replot the function
myplot1 = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200000],samples_y[1:200000],'.')

#Plot the box
plot([xmin, xmin], [ymin,ymax], color='k',linestyle='--')
plot([xmax, xmax], [ymin,ymax], color='k',linestyle='--')
plot([xmin, xmax], [ymax,ymax], color='k',linestyle='--')

# %%
newmask1 = (samples_y1 < f(samples_x1))

# %%
sum(newmask1)
# Out:
# 34553875

# %%
#Replot the function
myplot1 = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200000],samples_y[1:200000],'.')

#Show the ones below the function in red
plot(samples_x1[newmask1[:200000]],samples_y1[newmask1[:200000]],'r.')

#plot the box
plot([xmin, xmin], [ymin,ymax], color='k',linestyle='--')
plot([xmax, xmax], [ymin,ymax], color='k',linestyle='--')
plot([xmin, xmax], [ymax,ymax], color='k',linestyle='--')

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask1)/newmask1.size
print I
# Out:
# 26.5170515745

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print Iexact
print I
print 'error =',Ierr,'%'
# Out:
# 26.5172145362
# 26.5170515745
# error = 0.000614550472819 %
