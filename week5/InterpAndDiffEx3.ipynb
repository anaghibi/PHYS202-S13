# %% [markdown]
# ###Problem 1a)

# %%
from Electrostatics import *

# %%
x,y = meshgrid(arange(-5,5,0.5),arange(-5,5,0.5))
Vdipole = dipolePotential(x,y,1e-9,-1e-9,2.);
contour(x,y,Vdipole,cmap=cm.jet)
# Out:
# Electrostatics.py:12: RuntimeWarning: divide by zero encountered in divide
#   Vdipole = (k*q1/(x**2+(y-(d/2))**2)**(1/2.))-(k*q2/(x**2+(y+(d/2))**2)**(1/2.))
# <matplotlib.contour.QuadContourSet instance at 0x10b76bcb0>
